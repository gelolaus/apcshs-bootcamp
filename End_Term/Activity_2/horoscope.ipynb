# %%
# Created by Angelo John Benedict Laus
# For Asia Pacific College - SHS SoCIT Bootcamp A.Y. 2022-2023

# Ask for user's birth month (regardless if it's a number or a word) and birth date
month = input("What is your birth month? ").lower()
date = int(input("What is your birth date? "))

# Use if-elif-else statements to determine the user's zodiac sign
if month == "january" or month == "1":
    if date >= 1 and date <= 19:
        print("You are a Capricorn born on January", date)
    elif date >= 20 and date <= 31:
        print("You are an Aquarius born on January", date)
    else:
        print("Invalid date.")

elif month == "february" or month == "2":
    if date >= 1 and date <= 18:
        print("You are an Aquarius born on February", date)
    elif date >= 19 and date <= 29:
        print("You are a Pisces born on February", date)
    else:
        print("Invalid date.")

elif month == "march" or month == "3":
    if date >= 1 and date <= 20:
        print("You are a Pisces born on March", date)
    elif date >= 21 and date <= 31:
        print("You are an Aries born on March", date)
    else:
        print("Invalid date.")

elif month == "april" or month == "4":
    if date >= 1 and date <= 19:
        print("You are an Aries born on April", date)
    elif date >= 20 and date <= 30:
        print("You are a Taurus born on April", date)
    else:
        print("Invalid date.")

elif month == "may" or month == "5":
    if date >= 1 and date <= 20:
        print("You are a Taurus born on May", date)
    elif date >= 21 and date <= 31:
        print("You are a Gemini born on May", date)
    else:
        print("Invalid date.")

elif month == "june" or month == "6":
    if date >= 1 and date <= 20:
        print("You are a Gemini born on June", date)
    elif date >= 21 and date <= 30:
        print("You are a Cancer born on June", date)
    else:
        print("Invalid date.")

elif month == "july" or month == "7":
    if date >= 1 and date <= 22:
        print("You are a Cancer born on July", date)
    elif date >= 23 and date <= 31:
        print("You are a Leo born on July", date)
    else:
        print("Invalid date.")

elif month == "august" or month == "8":
    if date >= 1 and date <= 22:
        print("You are a Leo born on August", date)
    elif date >= 23 and date <= 31:
        print("You are a Virgo born on August", date)
    else:
        print("Invalid date.")

elif month == "september" or month == "9":
    if date >= 1 and date <= 22:
        print("You are a Virgo born on September", date)
    elif date >= 23 and date <= 30:
        print("You are a Libra born on September", date)
    else:
        print("Invalid date.")

elif month == "october" or month == "10":
    if date >= 1 and date <= 22:
        print("You are a Libra born on October", date)
    elif date >= 23 and date <= 31:
        print("You are a Scorpio born on October", date)
    else:
        print("Invalid date.")

elif month == "november" or month == "11":
    if date >= 1 and date <= 21:
        print("You are a Scorpio born on November", date)
    elif date >= 22 and date <= 30:
        print("You are a Sagittarius born on November", date)
    else:
        print("Invalid date.")

elif month == "december" or month == "12":
    if date >= 1 and date <= 21:
        print("You are a Sagittarius born on December", date)
    elif date >= 22 and date <= 31:
        print("You are a Capricorn born on December", date)
    else:
        print("Invalid date.")

else:
    print("Invalid month.")

# Generate 5 sentences defining horoscope.
print("Here are five things that you might experience today. \n 1. You will be lucky today. \n 2. You will meet someone special today. \n 3. You will have a great day today. \n 4. You will have a bad day today. \n 5. You will have a normal day today.")
# Out:
# What is your birth month? April
# What is your birth date? 23
# You are a Taurus born on April 23
# Here are five things that you might experience today.
#  1. You will be lucky today.
#  2. You will meet someone special today.
#  3. You will have a great day today.
#  4. You will have a bad day today.
#  5. You will have a normal day today.
